# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/Shareddrives/AD_detection_DA/
# Out:
# /content/gdrive/Shareddrives/AD_detection_DA

# %%
# !python code/feature_extraction.py
# Out:
# no_mmse_file .pickle saved
# DataFrame is written successfully to Excel File.
# data_w_feature .pickle saved
# DataFrame is written successfully to Excel File.

# %%
# !python code/model.py
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# 51
# 46
# {'fit_time': 0.26043, 'score_time': 0.02878, 'test_accuracy': 0.68298, 'test_precision': 0.73918, 'test_recall': 0.6282, 'test_f1': 0.66583}
